# %%
import pandas as pd
import numpy as np
import pygmt
from collections import Counter
import os
#import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
# Out:
# /tmp/ipykernel_287618/1883235070.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df_road = pd.read_csv("track_points.csv")
df_road.head()
# Out:
#            X         Y  track_fid  track_seg_id  track_seg_point_id  ele  \
# 0 -122.03165  46.75890          0             0                   0  NaN
# 1 -122.03149  46.75887          0             0                   1  NaN
# 2 -122.03119  46.75880          0             0                   2  NaN
# 3 -122.03075  46.75869          0             0                   3  NaN
# 4 -122.03012  46.75853          0             0                   4  NaN
#
#    time  magvar  geoidheight  name  ...  link2_type  sym  type  fix  sat  \
# 0   NaN     NaN          NaN   NaN  ...         NaN  NaN   NaN  NaN  NaN
# 1   NaN     NaN          NaN   NaN  ...         NaN  NaN   NaN  NaN  NaN
# 2   NaN     NaN          NaN   NaN  ...         NaN  NaN   NaN  NaN  NaN
# 3   NaN     NaN          NaN   NaN  ...         NaN  NaN   NaN  NaN  NaN
# 4   NaN     NaN          NaN   NaN  ...         NaN  NaN   NaN  NaN  NaN
#
#    hdop  vdop  pdop  ageofdgpsdata  dgpsid
# 0   NaN   NaN   NaN            NaN     NaN
# 1   NaN   NaN   NaN            NaN     NaN
# 2   NaN   NaN   NaN            NaN     NaN
# 3   NaN   NaN   NaN            NaN     NaN
# 4   NaN   NaN   NaN            NaN     NaN
#
# [5 rows x 28 columns]

# %%
#plt.plot(df_road['Distance_to_s'])
#plt.plot(df_road['Distance_to_e'])

# %%
# Assuming df_road is your DataFrame with "X" and "Y" columns representing longitude and latitude
df_road

# Start and end points
s_point = [46.771376, -121.786249]
e_point = [46.772903, -121.773978]


# Combine start and end points into a single array for efficient distance calculation
points = [[s_point[1], s_point[0]], [e_point[1], e_point[0]]]

# Calculate distances using Haversine formula
df_road['Distance_to_s'] = cdist(df_road[['X', 'Y']], [points[0]], metric='euclidean')
df_road['Distance_to_e'] = cdist(df_road[['X', 'Y']], [points[1]], metric='euclidean')

# Extract the part in-between
idx_min_s = df_road['Distance_to_s'].idxmin()
idx_min_e = df_road['Distance_to_e'].idxmin()
df_between = df_road.loc[min(idx_min_s, idx_min_e):max(idx_min_s, idx_min_e)]

# Print or use the results as needed
#print("Closest point to start:", closest_s_point)
#print("Closest point to end:", closest_e_point)
#print("Part in-between:")
print(df_between[['X', 'Y']])
# Out:
#              X         Y
# 558 -121.78618  46.77142
# 559 -121.78608  46.77151
# 560 -121.78598  46.77162
# 561 -121.78554  46.77293
# 562 -121.78544  46.77308
# ..         ...       ...
# 803 -121.77267  46.77339
# 804 -121.77302  46.77327
# 805 -121.77327  46.77318
# 806 -121.77354  46.77307
# 807 -121.77417  46.77283
#
# [250 rows x 2 columns]

# %%
# list of seismic? stations in Mt Rainier
df_seis = pd.read_csv("./MtRainier_seis.txt",sep="|")
print(df_seis.head())
df_seis["Station"]
# Out:
#   #Network Station   Latitude   Longitude  Elevation  \
# 0       CC    ARAT  46.789000 -121.853000    1822.44
# 1       CC    CARB  46.988320 -122.005410     872.47
# 2       CC    COPP  46.797980 -121.828750    1895.00
# 3       CC    CRBN  46.988155 -121.961026     500.08
# 4       CC    GNOB  46.794140 -121.914380    1659.36
#
#                       Sitename            StartTime              EndTime
# 0                 Mount Ararat  2020-08-06T00:00:00  2599-12-31T23:59:59
# 1              Carbon Repeater  2018-10-16T00:00:00  2599-12-31T23:59:59
# 2                         COPP  2022-09-20T11:00:00  2599-12-31T23:59:59
# 3  Carbon River Ranger Station  2020-10-22T00:00:00  2599-12-31T23:59:59
# 4        Gobblers Knob Seismic  2022-10-18T13:21:00  2599-12-31T23:59:59
# 0     ARAT
# 1     CARB
# 2     COPP
# 3     CRBN
# 4     GNOB
# 5     GOBB
# 6     GTWY
# 7     KAUT
# 8     MILD
# 9     OBSR
# 10    OPCH
# 11    PANH
# 12    PARA
# 13    PR01
# 14    PR02
# 15    PR03
# 16    PR04
# 17    PR05
# 18    RUSH
# 19    SIFT
# 20    SR41
# 21    STYX
# 22    TABR
# 23    TAVI
# 24    VOIT
# 25     WOW
# 26     ASF
# 27     DLR
# 28     FGM
# 29     FMW
# 30     GRL
# 31     LO2
# 32     LON
# 33     MHL
# 34     RCM
# 35     RCS
# 36     RER
# 37     RSH
# 38     RSU
# 39     RVC
# 40     RVN
# 41    STAR
# 42     WCR
# 43     WI2
# 44    WPEQ
# 45     WPS
# 46     WPW
# 47     XTL
# Name: Station, dtype: object

# %%
# create short station list including stations which detect avalanche on 2023-12-10T12:09
sta_list = ['RER', 'RCS', 'RCM', 'LON', 'LO2', 'SIFT', 'RUSH', 'PR05', 'PR04', 'PARA', 'PANH', 'OBSR', 'ARAT']
df_seis_short = df_seis[df_seis["Station"].isin(sta_list)]
df_seis_short
# Out:
#    #Network Station   Latitude   Longitude  Elevation  \
# 0        CC    ARAT  46.789000 -121.853000    1822.44
# 9        CC    OBSR  46.899719 -121.815331    2382.00
# 11       CC    PANH  46.859032 -121.642592    2086.00
# 12       CC    PARA  46.786441 -121.742195    1651.18
# 16       CC    PR04  46.929773 -121.988592     908.00
# 17       CC    PR05  46.841723 -121.948863    1553.00
# 18       CC    RUSH  46.903050 -121.944190    1235.00
# 19       CC    SIFT  46.866830 -121.953290     732.00
# 31       UW     LO2  46.750599 -121.809601     853.00
# 32       UW     LON  46.750599 -121.809601     853.00
# 34       UW     RCM  46.835640 -121.732980    3077.00
# 35       UW     RCS  46.870831 -121.732307    2877.00
# 36       UW     RER  46.818580 -121.842500    1751.10
#
#                                  Sitename            StartTime  \
# 0                            Mount Ararat  2020-08-06T00:00:00
# 9                        Observation Rock  2008-11-19T00:00:00
# 11                          Panhandle Gap  2007-09-10T00:00:00
# 12                  Paradise Precip Tower  2020-10-07T00:00:00
# 16                      Puyallup River 04  2017-01-01T00:00:00
# 17                      Puyallup River 05  2017-09-28T00:00:00
# 18                     Rushingwater Creek  2019-06-20T00:00:00
# 19                            Swift Creek  2019-06-20T00:00:00
# 31                  Longmire short period  1988-03-17T00:00:00
# 32              Longmire CREST broad-band  1964-03-30T00:00:00
# 34      Camp Muir, Mount Rainier, WA, USA  1993-09-09T00:00:00
# 35             Mt. Rainier, Camp Schurman  1989-06-27T00:00:00
# 36  Emerald Ridge, Mount Rainier, WA, USA  1989-07-13T00:00:00
#
#                 EndTime
# 0   2599-12-31T23:59:59
# 9   2599-12-31T23:59:59
# 11  2599-12-31T23:59:59
# 12  2599-12-31T23:59:59
# 16  2599-12-31T23:59:59
# 17  2599-12-31T23:59:59
# 18  2599-12-31T23:59:59
# 19  2599-12-31T23:59:59
# 31  2599-12-31T23:59:59
# 32  2599-12-31T23:59:59
# 34  2599-12-31T23:59:59
# 35  2599-12-31T23:59:59
# 36  2599-12-31T23:59:59

# %%
# loading swarm 

df_swarm = pd.read_csv("pnsn_event_export_5dias.csv")
df_swarm.head()
# [359 rows x 11 columns]

# %%
df_template = pd.read_csv("template-location.csv")
df_template.head()
# Out:
#        Evid  Magnitude Magnitude Type    Epoch(UTC)             Time UTC  \
# 0  61953701        2.9              l  1.693131e+09  2023/08/27 10:10:23
#
#                 Time Local                Distance From      Lat      Lon  \
# 0  2023/08/27 03:10:23 PDT  17.8 km from Mt Rainier, WA  46.7678 -121.957
#
#    Depth Km  Depth Mi
# 0       9.7       6.0

# %%
fig = pygmt.Figure()
RR=[-122.1, -121.45, 46.65, 47.]
# RR=[-123, -120, 46, 48]
grid = pygmt.datasets.load_earth_relief(resolution="03s", region=RR)
fig.shift_origin(yshift="10c")
fig.grdimage(grid=grid, projection="M15c", frame="a", cmap="geo", transparency = 30)
fig.colorbar(position = 'JMB+w9.+o3.c/1.c', frame='af+l"Elevation (m)"')


# pygmt.makecpt(cmap="gray", series=[min(dep)-5, 30],reverse=True)
# pygmt.makecpt(cmap="gray", series=[min(dep)-5, 30],reverse=True)
# fig.plot(x = lon_eq, y = lat_eq, color = dep_eq, size = osize_eq,cmap = True, style = "c", pen = "black")
# fig.plot(x = lon_ex, y = lat_ex, style="p1c", pen="1p,black", fill="white")
# fig.plot(x = reg_auth[:, 0], y = reg_auth[:, 1], pen = '2.p,red3,-')
# fig.colorbar(position = 'JMB+w7.+o-4.c/1.c', frame='af+l"Event Depth (km)"')

# plot road for the DAS
fig.plot(x=df_road["X"],y= df_road["Y"],pen = '3p,purple', label='DAS array')
#fig.plot(x=df_between["X"],y= df_between["Y"],pen = '3p,red', label='section shown in a)')


# plot stations
# fig.plot(x = df_infra["Longitude"], y = df_infra["Latitude"],style="t0.8c",size=nexp_infra, pen="1p,blue", fill="blue")
fig.plot(x = df_seis["Longitude"], y = df_seis["Latitude"],
         style="i0.50c", pen="1p,black", fill="black", transparency=30)
# fig.plot(x = df_seis_short["Longitude"], y = df_seis_short["Latitude"],
#         style="i0.75c", pen="1p,black", fill="red")
fig.plot(x = df_seismicity["Lon"], y= df_seismicity["Lat"],
          style="c0.20c", pen="1p,black", fill="gray")

fig.plot(x = df_swarm["Lon"], y= df_swarm["Lat"],
          style="c0.20c", pen="1p,black", fill="yellow")
fig.plot(x = df_template["Lon"], y= df_template["Lat"],
          style="c0.30c", pen="1p,black", fill="red")



# # legende
fig.plot(
    x=np.nan, y=np.nan, style="i0.6c", pen="1p,black", fill="black",
    label='PNSN+CVO network')
fig.plot(
    x=np.nan, y=np.nan, style="c0.25c", pen="1p,black", fill="yellow",
    label='PNSN detection')
fig.plot(
    x=np.nan, y=np.nan, style="c0.25c", pen="1p,black", fill="red",
    label='Template event')
fig.plot(
    x=np.nan, y=np.nan, style="c0.25c", pen="1p,black", fill="gray",
    label='Events since 8/25/2023')

#fig.plot(
#    x=np.nan, y=np.nan, style="i0.6c", pen="1p,black", fill="red",
#    label='station shown in b)')
# fig.plot(
#     x=np.nan, y=np.nan, pen = '3p,black',
#     label='Cable section')
# fig.plot(
#     x=np.nan, y=np.nan, pen = '3p,red',
#     label='Cable section')

# fig.legend(transparency=15, box="+gwhite+p1p", position="jTR+jTR+w5.c/2.5c+o0.1c")

# adjust font size only for legend
with pygmt.config(FONT_ANNOT_PRIMARY="14p"):
    fig.legend(transparency=15)

fig.show()
fig.savefig("./map_seis_das_swarm_2023-08-26.png", dpi=800)
# Out:
# plot [WARNING]: Modifier +C detected but not a valid modifier! - ignored
